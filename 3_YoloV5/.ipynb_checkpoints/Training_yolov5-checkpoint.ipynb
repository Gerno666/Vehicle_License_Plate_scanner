# %%
import os

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12209, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 12209 (delta 0), reused 4 (delta 0), pack-reused 12197
# Receiving objects: 100% (12209/12209), 12.61 MiB | 1.31 MiB/s, done.
# Resolving deltas: 100% (8404/8404), done.

# %%
# %%bash
# cd yolov5
# pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.0/174.0 kB 1.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 1.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 1.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.1/285.1 kB 1.8 MB/s eta 0:00:00
# ...
#   Using cached protobuf-3.19.4-cp310-cp310-macosx_10_9_universal2.whl (961 kB)
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.1
#     Uninstalling protobuf-3.20.1:
#       Successfully uninstalled protobuf-3.20.1
# ...

# %%
# !python yolov5/train.py --data yolov5/data.yaml --weights yolov5s.pt --batch-size 8 --name Model --img 640 --epochs 150
# Out:
# train: weights=yolov5s.pt, cfg=, data=yolov5/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=150, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=Model, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# fatal: cannot change to '/Users/niccoloerasmi/Desktop/Progetto': No such file or directory
# YOLOv5 🚀 2022-9-8 Python-3.10.6 torch-1.12.1 CPU
#
# ...

# %%
# !python yolov5/export.py --weights yolov5/runs/train/Model2/weights/best.pt --include onnx --simplify
# Out:
# export: data=yolov5/data/coco128.yaml, weights=['yolov5/runs/train/Model2/weights/best.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, train=False, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=12, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['onnx']
# YOLOv5 🚀 v6.2-97-g903b239 Python-3.10.6 torch-1.12.1 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
#
# PyTorch: starting from yolov5/runs/train/Model2/weights/best.pt with output shape (1, 25200, 6) (13.7 MB)
#
# ONNX: starting export with onnx 1.12.0...
# ONNX: simplifying with onnx-simplifier 0.4.8...
# ONNX: export success ✅ 2.2s, saved as yolov5/runs/train/Model2/weights/best.onnx (27.2 MB)
#
# Export complete (2.4s)
# Results saved to /Users/niccoloerasmi/Desktop/ProgettoLabIA/Module_4_YoloV5/yolov5/runs/train/Model2/weights
# ...
